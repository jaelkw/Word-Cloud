# %%
# Ref:
# https://www.datacamp.com/community/tutorials/wordcloud-python

# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path, walk
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from datetime import datetime

import matplotlib.pyplot as plt
# % matplotlib inline

# %%
date_string = datetime.strftime(datetime.today(),"%d%m%Y")

        
source_file = "All_combined_03062020.txt"
text = open(source_file, 'r').read().replace(" *@* ","")

# Generate word cloud with desired parameters
wordcloud = WordCloud(width=1600, height=800, background_color="white").generate(text)

# %%
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
